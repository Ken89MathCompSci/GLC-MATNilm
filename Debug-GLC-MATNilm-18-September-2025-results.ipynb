# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/GLC-MATNilm/blob/kengoh-f1-score-issues/Debug-GLC-MATNilm-18-September-2025-results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
cd GLC-MATNilm/
# Out:
# /content/GLC-MATNilm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/GLC-MATNilm
# Out:
# /content/GLC-MATNilm

# %%
# !python main.py --subName colab_train
# Out:
# 2025-09-18 17:33:29,024 - root - INFO - Using computation device: cuda:0
# 2025-09-18 17:33:29,024 - root - INFO - Namespace(batch=32, lr=0.001, dropout=0.1, hidden=32, logname='root', subName='colab_train', inputLength=864, outputLength=864, debug=False, dataAug=False, prob0=0.3, prob1=0.6, prob2=0.3, prob3=0.3, test=False, show_graph=False)
# 2025-09-18 17:33:29,024 - root - INFO - loading data
# 2025-09-18 17:33:29,055 - root - INFO - loading data finished
# mkdir: cannot create directory ‘datacolab_train’: File exists
# 2025-09-18 17:33:29,058 - root - INFO - Training size: 27937.
# ...

# %%
import os
os.makedirs('/content/GLC-MATNilm/history_model/colab_train/s0', exist_ok=True)

# %%
import os
os.makedirs('/content/GLC-MATNilm/log/colab_train', exist_ok=True)
