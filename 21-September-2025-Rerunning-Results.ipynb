# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/GLC-MATNilm/blob/kengoh-learnable-positional-encoding-only/21-September-2025-Rerunning-Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
cd GLC-MATNilm/
# Out:
# /content/GLC-MATNilm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/GLC-MATNilm
# Out:
# /content/GLC-MATNilm

# %%
import os
os.makedirs('/content/GLC-MATNilm/history_model/colab_train/s0', exist_ok=True)

# %%
import os
os.makedirs('/content/GLC-MATNilm/log/colab_train', exist_ok=True)

# %%
# !python main.py --dataAug --subName colab_train --output_dir "/content/drive/My Drive/GLC-MATNilm_results"
# Out:
# usage: main.py [-h] [--batch BATCH] [--lr LR] [--dropout DROPOUT]
#                [--hidden HIDDEN] [--logname LOGNAME] [--subName SUBNAME]
#                [--inputLength INPUTLENGTH] [--outputLength OUTPUTLENGTH]
#                [--debug] [--dataAug] [--prob0 PROB0] [--prob1 PROB1]
#                [--prob2 PROB2] [--prob3 PROB3] [--resume]
#                [--checkpoint CHECKPOINT]
# main.py: error: unrecognized arguments: --output_dir /content/drive/My Drive/GLC-MATNilm_results

# %%
import copy
import os
import utils
import argparse
import joblib
from tqdm import tqdm
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from custom_types import Basic, TrainConfig
from modules import MATconv as MAT
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
import sys # Import the sys module


def get_args():
    parser = argparse.ArgumentParser()

    parser.add_argument("--batch", type=int, default=32, help="batch size")
    parser.add_argument("--lr", type=float, default=0.001, help="learning rate")
    parser.add_argument("--dropout", type=float, default=0.1, help="dropout")
    parser.add_argument("--hidden", type=int, default=32, help="encoder decoder hidden size")
    parser.add_argument("--logname", action="store", default='root', help="name for log")
    parser.add_argument("--subName", action="store", type=str, default='test', help="name of the directory of current run")
    parser.add_argument("--inputLength", type=int, default=864, help="input length for the model")
    parser.add_argument("--outputLength", type=int, default=864, help="output length for the model")
    parser.add_argument("--debug", action="store_true", help="debug mode")
    parser.add_argument("--dataAug", action="store_true", help="data augmentation mode")
    parser.add_argument("--prob0", type=float, default=0.3, help="augment probability for Dishwasher")
    parser.add_argument("--prob1", type=float, default=0.6, help="weight")
    parser.add_argument("--prob2", type=float, default=0.3, help="weight")
    parser.add_argument("--prob3", type=float, default=0.3, help="weight")
    parser.add_argument("--resume", action="store_true", help="resume training from checkpoint")
    parser.add_argument("--checkpoint", type=str, default="All_best_onoff.ckpt", help="checkpoint file name to resume from")
    parser.add_argument("--output_dir", type=str, default=".", help="directory to save output results") # Added output_dir argument

    # Workaround for Colab's kernel launcher adding extra arguments
    if '__file__' not in globals():
        sys.argv = [sys.argv[0]]

    return parser.parse_args()


def train(t_net, train_Dataloader, vali_Dataloader, config, criterion, modelDir, epo=200):
    iter_loss = []
    vali_loss = []
    early_stopping_all = utils.EarlyStopping(logger, patience=30, verbose=True)

    if config.dataAug:
        sigClass = utils.sigGen(config)

    path_all = os.path.join(modelDir, "All_best_onoff.ckpt")

    for e_i in range(epo):

        logger.info(f"# of epoches: {e_i}")
        for t_i, (_, _, X_scaled, Y_scaled, Y_of) in enumerate(tqdm(train_Dataloader)):
            if config.dataAug:
                X_scaled, Y_scaled, Y_of = utils.dataAug(X_scaled.clone(), Y_scaled.clone(), Y_of.clone(), sigClass, config)

            t_net.model_opt.zero_grad(set_to_none=True)

            X_scaled = X_scaled.type(torch.FloatTensor).to(device, non_blocking=True)
            Y_scaled = Y_scaled.type(torch.FloatTensor).to(device, non_blocking=True)
            Y_of = Y_of.type(torch.FloatTensor).to(device, non_blocking=True)

            y_pred_dish_r, y_pred_dish_c = t_net.model(X_scaled)

            loss_r = criterion[0](y_pred_dish_r,Y_scaled)
            loss_c = criterion[1](y_pred_dish_c, Y_of)

            loss=loss_r+loss_c
            loss.backward()

            t_net.model_opt.step()
            iter_loss.append(loss.item())

        epoch_losses = np.average(iter_loss)

        logger.info(f"Validation: ")
        maeScore, y_vali_ori, y_vali_pred_d_update, _, _, _ = utils.evaluateResult(net, config, vali_Dataloader, logger)
        val_loss = criterion[0](y_vali_ori, y_vali_pred_d_update)
        logger.info(f"Epoch {e_i:d}, train loss: {epoch_losses:3.3f}, val loss: {val_loss:3.3f}.")
        vali_loss.append(val_loss)

        if e_i % 10 == 0:
            checkpointName = os.path.join(modelDir, "checkpoint_" + str(e_i) + '.ckpt')
            utils.saveModel(logger, net, checkpointName)

        logger.info(f"Early stopping overall: ")
        early_stopping_all(np.mean(maeScore), net, path_all)
        if early_stopping_all.early_stop:
            print("Early stopping")
            break

    net_all = copy.deepcopy(net)
    checkpoint_all = torch.load(path_all, map_location=device)
    utils.loadModel(logger, net_all, checkpoint_all)
    net_all.model.eval()

    return net_all

if __name__ == '__main__':
    args = get_args()
    utils.mkdir("log/" + args.subName)
    logger = utils.setup_log(args.subName, args.logname)
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    logger.info(f"Using computation device: {device}")
    logger.info(args)
    if args.debug:
        epo = 2
    else:
        epo = 200

    # splitLoss = False
    # trainFull = True

    # Dataloder
    logger.info(f"loading data")
    train_data, val_data, test_data = utils.data_loader(args)

    logger.info(f"loading data finished")

    config_dict = {
        "input_size": 1,
        "batch_size": args.batch,
        "hidden": args.hidden,
        "lr": args.lr,
        "dropout": args.dropout,
        "logname": args.logname,
        "outputLength": args.outputLength,
        "inputLength" : args.inputLength,
        "subName": args.subName,
        "dataAug": args.dataAug,
        "prob0": args.prob0,
        "prob1": args.prob1,
        "prob2": args.prob2,
        "prob3": args.prob3,
        "output_dir": args.output_dir # Added to config
    }

    config = TrainConfig.from_dict(config_dict)
    modelDir = utils.mkdirectory(config.subName, saveModel=True) # This needs to be updated to use output_dir
    joblib.dump(config, os.path.join(modelDir, "config.pkl"))


    logger.info(f"Training size: {train_data.cumulative_sizes[-1]:d}.")

    index = np.arange(0,train_data.cumulative_sizes[-1])
    train_subsampler = torch.utils.data.SubsetRandomSampler(index)
    train_Dataloader = DataLoader(
        train_data,
        batch_size=config.batch_size,
        sampler=train_subsampler,
        num_workers=1,
        pin_memory=True)

    sampler = utils.testSampler(val_data.cumulative_sizes[-1], config.outputLength)
    sampler_test = utils.testSampler(test_data.cumulative_sizes[-1], config.outputLength)

    vali_Dataloader = DataLoader(
        val_data,
        batch_size=config.batch_size,
        sampler=sampler,
        num_workers=1,
        pin_memory=True)

    test_Dataloader = DataLoader(
        test_data,
        batch_size=config.batch_size,
        sampler=sampler_test,
        num_workers=1,
        pin_memory=True)

    logger.info("Initialize model")
    model = MAT(config).to(device)
    logger.info("Model MAT")

    optim = optim.Adam(params=[p for p in model.parameters() if p.requires_grad], lr=config.lr)
    net = Basic(model, optim)

    # Resume from checkpoint if specified
    if args.resume:
        checkpoint_path = os.path.join(modelDir, args.checkpoint)
        if os.path.exists(checkpoint_path):
            logger.info(f"Resuming training from checkpoint: {checkpoint_path}")
            checkpoint = torch.load(checkpoint_path, map_location=device)
            net = utils.loadModel(logger, net, checkpoint)
        else:
            logger.error(f"Checkpoint file not found: {checkpoint_path}")
            logger.info("Starting training from scratch")

    criterion_r = nn.MSELoss()
    criterion_c = nn.BCELoss()
    criterion = [criterion_r, criterion_c]

    logger.info("Training start")
    net_all = train(net, train_Dataloader, vali_Dataloader, config, criterion, modelDir, epo=epo)
    logger.info("Training end")

    logger.info("validation start")
    utils.evaluateResult(net_all, config, vali_Dataloader, logger)
    logger.info("test start")
    utils.evaluateResult(net_all, config, test_Dataloader, logger)
# Out:
# INFO:root:Using computation device: cuda:0
# 2025-09-20 18:16:35,469 - root - INFO - Using computation device: cuda:0
# INFO:root:Namespace(batch=32, lr=0.001, dropout=0.1, hidden=32, logname='root', subName='test', inputLength=864, outputLength=864, debug=False, dataAug=False, prob0=0.3, prob1=0.6, prob2=0.3, prob3=0.3, resume=False, checkpoint='All_best_onoff.ckpt', output_dir='.')
# 2025-09-20 18:16:35,470 - root - INFO - Namespace(batch=32, lr=0.001, dropout=0.1, hidden=32, logname='root', subName='test', inputLength=864, outputLength=864, debug=False, dataAug=False, prob0=0.3, prob1=0.6, prob2=0.3, prob3=0.3, resume=False, checkpoint='All_best_onoff.ckpt', output_dir='.')
# INFO:root:loading data
# 2025-09-20 18:16:35,472 - root - INFO - loading data
# INFO:root:loading data finished
# 2025-09-20 18:16:35,520 - root - INFO - loading data finished
# INFO:root:Training size: 27937.
# 2025-09-20 18:16:35,529 - root - INFO - Training size: 27937.
# INFO:root:Initialize model
# 2025-09-20 18:16:35,531 - root - INFO - Initialize model
# INFO:root:Model MAT
# 2025-09-20 18:16:35,800 - root - INFO - Model MAT
# INFO:root:Training start
# 2025-09-20 18:16:44,563 - root - INFO - Training start
# INFO:root:# of epoches: 0
# 2025-09-20 18:16:44,565 - root - INFO - # of epoches: 0
#   0%|          | 0/874 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:366: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1027.)
#   return F.conv1d(
# 100%|██████████| 874/874 [16:37<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-20 18:33:21,717 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 18:33:22,052 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 30.479148864746094
# 2025-09-20 18:33:22,055 - root - INFO - MAE: 30.479148864746094
# INFO:root:SAE: 31.364316940307617
# 2025-09-20 18:33:22,058 - root - INFO - SAE: 31.364316940307617
# INFO:root:F1: 0.0
# 2025-09-20 18:33:22,074 - root - INFO - F1: 0.0
# INFO:root:Evaluate fridge:
# 2025-09-20 18:33:22,075 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 33.6806526184082
# 2025-09-20 18:33:22,077 - root - INFO - MAE: 33.6806526184082
# INFO:root:SAE: 21.021865844726562
# 2025-09-20 18:33:22,079 - root - INFO - SAE: 21.021865844726562
# INFO:root:F1: 0.7640631635844176
# 2025-09-20 18:33:22,088 - root - INFO - F1: 0.7640631635844176
# INFO:root:Evaluate microwave:
# 2025-09-20 18:33:22,090 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 24.21089744567871
# 2025-09-20 18:33:22,092 - root - INFO - MAE: 24.21089744567871
# INFO:root:SAE: 22.450899124145508
# 2025-09-20 18:33:22,095 - root - INFO - SAE: 22.450899124145508
# INFO:root:F1: 0.1018262313226342
# 2025-09-20 18:33:22,104 - root - INFO - F1: 0.1018262313226342
# INFO:root:Evaluate wash:
# 2025-09-20 18:33:22,105 - root - INFO - Evaluate wash:
# INFO:root:MAE: 16.35631561279297
# 2025-09-20 18:33:22,107 - root - INFO - MAE: 16.35631561279297
# INFO:root:SAE: 8.731846809387207
# 2025-09-20 18:33:22,110 - root - INFO - SAE: 8.731846809387207
# INFO:root:F1: 0.9376681089931003
# 2025-09-20 18:33:22,118 - root - INFO - F1: 0.9376681089931003
# INFO:root:Epoch 0, train loss: 0.113, val loss: 12933.728.
# 2025-09-20 18:33:22,127 - root - INFO - Epoch 0, train loss: 0.113, val loss: 12933.728.
# INFO:root:Model saved
# 2025-09-20 18:33:22,250 - root - INFO - Model saved
# INFO:root:Early stopping overall:
# 2025-09-20 18:33:22,254 - root - INFO - Early stopping overall:
# INFO:root:Validation loss decreased (inf --> 26.181755).  Saving model ...
# 2025-09-20 18:33:22,256 - root - INFO - Validation loss decreased (inf --> 26.181755).  Saving model ...
# INFO:root:Model saved
# 2025-09-20 18:33:22,372 - root - INFO - Model saved
# INFO:root:# of epoches: 1
# 2025-09-20 18:33:22,374 - root - INFO - # of epoches: 1
# 100%|██████████| 874/874 [16:34<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-20 18:49:57,015 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 18:49:57,336 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 30.54875373840332
# 2025-09-20 18:49:57,338 - root - INFO - MAE: 30.54875373840332
# INFO:root:SAE: 31.424272537231445
# 2025-09-20 18:49:57,341 - root - INFO - SAE: 31.424272537231445
# INFO:root:F1: 0.0
# 2025-09-20 18:49:57,353 - root - INFO - F1: 0.0
# INFO:root:Evaluate fridge:
# 2025-09-20 18:49:57,355 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 35.89750671386719
# 2025-09-20 18:49:57,357 - root - INFO - MAE: 35.89750671386719
# INFO:root:SAE: 21.03996467590332
# 2025-09-20 18:49:57,359 - root - INFO - SAE: 21.03996467590332
# INFO:root:F1: 0.7434095617206223
# 2025-09-20 18:49:57,368 - root - INFO - F1: 0.7434095617206223
# INFO:root:Evaluate microwave:
# 2025-09-20 18:49:57,370 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 28.53584098815918
# 2025-09-20 18:49:57,373 - root - INFO - MAE: 28.53584098815918
# INFO:root:SAE: 11.849665641784668
# 2025-09-20 18:49:57,375 - root - INFO - SAE: 11.849665641784668
# INFO:root:F1: 0.14035087719298245
# 2025-09-20 18:49:57,384 - root - INFO - F1: 0.14035087719298245
# INFO:root:Evaluate wash:
# 2025-09-20 18:49:57,386 - root - INFO - Evaluate wash:
# INFO:root:MAE: 20.625852584838867
# 2025-09-20 18:49:57,388 - root - INFO - MAE: 20.625852584838867
# INFO:root:SAE: 16.14410400390625
# 2025-09-20 18:49:57,391 - root - INFO - SAE: 16.14410400390625
# INFO:root:F1: 0.9368747022391615
# 2025-09-20 18:49:57,399 - root - INFO - F1: 0.9368747022391615
# INFO:root:Epoch 1, train loss: 0.064, val loss: 17887.023.
# 2025-09-20 18:49:57,401 - root - INFO - Epoch 1, train loss: 0.064, val loss: 17887.023.
# INFO:root:Early stopping overall:
# 2025-09-20 18:49:57,403 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 1 out of 30
# 2025-09-20 18:49:57,404 - root - INFO - EarlyStopping counter: 1 out of 30
# INFO:root:# of epoches: 2
# 2025-09-20 18:49:57,406 - root - INFO - # of epoches: 2
# 100%|██████████| 874/874 [16:34<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-20 19:06:32,394 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 19:06:32,716 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 42.82798385620117
# 2025-09-20 19:06:32,719 - root - INFO - MAE: 42.82798385620117
# INFO:root:SAE: 43.6210823059082
# 2025-09-20 19:06:32,722 - root - INFO - SAE: 43.6210823059082
# INFO:root:F1: 0.0
# 2025-09-20 19:06:32,732 - root - INFO - F1: 0.0
# INFO:root:Evaluate fridge:
# 2025-09-20 19:06:32,734 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 34.76848220825195
# 2025-09-20 19:06:32,736 - root - INFO - MAE: 34.76848220825195
# INFO:root:SAE: 17.944164276123047
# 2025-09-20 19:06:32,738 - root - INFO - SAE: 17.944164276123047
# INFO:root:F1: 0.7358535998073682
# 2025-09-20 19:06:32,746 - root - INFO - F1: 0.7358535998073682
# INFO:root:Evaluate microwave:
# 2025-09-20 19:06:32,747 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 24.168149948120117
# 2025-09-20 19:06:32,749 - root - INFO - MAE: 24.168149948120117
# INFO:root:SAE: 23.30686378479004
# 2025-09-20 19:06:32,751 - root - INFO - SAE: 23.30686378479004
# INFO:root:F1: 0.09345794392523364
# 2025-09-20 19:06:32,759 - root - INFO - F1: 0.09345794392523364
# INFO:root:Evaluate wash:
# 2025-09-20 19:06:32,760 - root - INFO - Evaluate wash:
# INFO:root:MAE: 16.42867088317871
# 2025-09-20 19:06:32,762 - root - INFO - MAE: 16.42867088317871
# INFO:root:SAE: 10.179497718811035
# 2025-09-20 19:06:32,764 - root - INFO - SAE: 10.179497718811035
# INFO:root:F1: 0.9416851700362276
# 2025-09-20 19:06:32,772 - root - INFO - F1: 0.9416851700362276
# INFO:root:Epoch 2, train loss: 0.061, val loss: 15540.863.
# 2025-09-20 19:06:32,774 - root - INFO - Epoch 2, train loss: 0.061, val loss: 15540.863.
# INFO:root:Early stopping overall:
# 2025-09-20 19:06:32,776 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 2 out of 30
# 2025-09-20 19:06:32,777 - root - INFO - EarlyStopping counter: 2 out of 30
# INFO:root:# of epoches: 3
# 2025-09-20 19:06:32,779 - root - INFO - # of epoches: 3
# 100%|██████████| 874/874 [16:35<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-20 19:23:08,207 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 19:23:08,536 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 33.9621467590332
# 2025-09-20 19:23:08,538 - root - INFO - MAE: 33.9621467590332
# INFO:root:SAE: 34.9277458190918
# 2025-09-20 19:23:08,540 - root - INFO - SAE: 34.9277458190918
# INFO:root:F1: 0.0
# 2025-09-20 19:23:08,549 - root - INFO - F1: 0.0
# INFO:root:Evaluate fridge:
# 2025-09-20 19:23:08,551 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 37.40463638305664
# 2025-09-20 19:23:08,553 - root - INFO - MAE: 37.40463638305664
# INFO:root:SAE: 21.547704696655273
# 2025-09-20 19:23:08,555 - root - INFO - SAE: 21.547704696655273
# INFO:root:F1: 0.7263656977942692
# 2025-09-20 19:23:08,562 - root - INFO - F1: 0.7263656977942692
# INFO:root:Evaluate microwave:
# 2025-09-20 19:23:08,564 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 27.571182250976562
# 2025-09-20 19:23:08,565 - root - INFO - MAE: 27.571182250976562
# INFO:root:SAE: 25.278640747070312
# 2025-09-20 19:23:08,567 - root - INFO - SAE: 25.278640747070312
# INFO:root:F1: 0.011661807580174927
# 2025-09-20 19:23:08,574 - root - INFO - F1: 0.011661807580174927
# INFO:root:Evaluate wash:
# 2025-09-20 19:23:08,576 - root - INFO - Evaluate wash:
# INFO:root:MAE: 19.49989128112793
# 2025-09-20 19:23:08,578 - root - INFO - MAE: 19.49989128112793
# INFO:root:SAE: 11.540040016174316
# 2025-09-20 19:23:08,580 - root - INFO - SAE: 11.540040016174316
# INFO:root:F1: 0.9022152606847169
# 2025-09-20 19:23:08,588 - root - INFO - F1: 0.9022152606847169
# INFO:root:Epoch 3, train loss: 0.049, val loss: 18000.930.
# 2025-09-20 19:23:08,590 - root - INFO - Epoch 3, train loss: 0.049, val loss: 18000.930.
# INFO:root:Early stopping overall:
# 2025-09-20 19:23:08,592 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 3 out of 30
# 2025-09-20 19:23:08,593 - root - INFO - EarlyStopping counter: 3 out of 30
# INFO:root:# of epoches: 4
# 2025-09-20 19:23:08,595 - root - INFO - # of epoches: 4
# 100%|██████████| 874/874 [16:35<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-20 19:39:44,033 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 19:39:44,356 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 30.886560440063477
# 2025-09-20 19:39:44,358 - root - INFO - MAE: 30.886560440063477
# INFO:root:SAE: 31.779651641845703
# 2025-09-20 19:39:44,361 - root - INFO - SAE: 31.779651641845703
# INFO:root:F1: 0.0
# 2025-09-20 19:39:44,372 - root - INFO - F1: 0.0
# INFO:root:Evaluate fridge:
# 2025-09-20 19:39:44,374 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 33.937644958496094
# 2025-09-20 19:39:44,375 - root - INFO - MAE: 33.937644958496094
# INFO:root:SAE: 19.99622344970703
# 2025-09-20 19:39:44,378 - root - INFO - SAE: 19.99622344970703
# INFO:root:F1: 0.7469105691056911
# 2025-09-20 19:39:44,386 - root - INFO - F1: 0.7469105691056911
# INFO:root:Evaluate microwave:
# 2025-09-20 19:39:44,388 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 33.23230743408203
# 2025-09-20 19:39:44,390 - root - INFO - MAE: 33.23230743408203
# INFO:root:SAE: 25.13180923461914
# 2025-09-20 19:39:44,391 - root - INFO - SAE: 25.13180923461914
# INFO:root:F1: 0.037399821905609976
# 2025-09-20 19:39:44,399 - root - INFO - F1: 0.037399821905609976
# INFO:root:Evaluate wash:
# 2025-09-20 19:39:44,404 - root - INFO - Evaluate wash:
# INFO:root:MAE: 14.63785457611084
# 2025-09-20 19:39:44,405 - root - INFO - MAE: 14.63785457611084
# INFO:root:SAE: 6.605996608734131
# 2025-09-20 19:39:44,407 - root - INFO - SAE: 6.605996608734131
# INFO:root:F1: 0.9471463729051917
# 2025-09-20 19:39:44,417 - root - INFO - F1: 0.9471463729051917
# INFO:root:Epoch 4, train loss: 0.045, val loss: 16824.660.
# 2025-09-20 19:39:44,422 - root - INFO - Epoch 4, train loss: 0.045, val loss: 16824.660.
# INFO:root:Early stopping overall:
# 2025-09-20 19:39:44,423 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 4 out of 30
# 2025-09-20 19:39:44,425 - root - INFO - EarlyStopping counter: 4 out of 30
# INFO:root:# of epoches: 5
# 2025-09-20 19:39:44,427 - root - INFO - # of epoches: 5
# 100%|██████████| 874/874 [16:36<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-20 19:56:21,230 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 19:56:21,597 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 31.42812156677246
# 2025-09-20 19:56:21,601 - root - INFO - MAE: 31.42812156677246
# INFO:root:SAE: 32.298343658447266
# 2025-09-20 19:56:21,604 - root - INFO - SAE: 32.298343658447266
# INFO:root:F1: 0.002140181915462814
# 2025-09-20 19:56:21,615 - root - INFO - F1: 0.002140181915462814
# INFO:root:Evaluate fridge:
# 2025-09-20 19:56:21,617 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 35.57844161987305
# 2025-09-20 19:56:21,618 - root - INFO - MAE: 35.57844161987305
# INFO:root:SAE: 23.723142623901367
# 2025-09-20 19:56:21,620 - root - INFO - SAE: 23.723142623901367
# INFO:root:F1: 0.7541570530670698
# 2025-09-20 19:56:21,627 - root - INFO - F1: 0.7541570530670698
# INFO:root:Evaluate microwave:
# 2025-09-20 19:56:21,629 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 29.531282424926758
# 2025-09-20 19:56:21,631 - root - INFO - MAE: 29.531282424926758
# INFO:root:SAE: 24.758909225463867
# 2025-09-20 19:56:21,633 - root - INFO - SAE: 24.758909225463867
# INFO:root:F1: 0.03666361136571952
# 2025-09-20 19:56:21,640 - root - INFO - F1: 0.03666361136571952
# INFO:root:Evaluate wash:
# 2025-09-20 19:56:21,641 - root - INFO - Evaluate wash:
# INFO:root:MAE: 14.021361351013184
# 2025-09-20 19:56:21,643 - root - INFO - MAE: 14.021361351013184
# INFO:root:SAE: 7.705133438110352
# 2025-09-20 19:56:21,645 - root - INFO - SAE: 7.705133438110352
# INFO:root:F1: 0.9336470588235294
# 2025-09-20 19:56:21,653 - root - INFO - F1: 0.9336470588235294
# INFO:root:Epoch 5, train loss: 0.038, val loss: 14762.895.
# 2025-09-20 19:56:21,655 - root - INFO - Epoch 5, train loss: 0.038, val loss: 14762.895.
# INFO:root:Early stopping overall:
# 2025-09-20 19:56:21,656 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 5 out of 30
# 2025-09-20 19:56:21,658 - root - INFO - EarlyStopping counter: 5 out of 30
# INFO:root:# of epoches: 6
# 2025-09-20 19:56:21,659 - root - INFO - # of epoches: 6
# 100%|██████████| 874/874 [16:36<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-20 20:12:57,718 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 20:12:58,044 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 29.625394821166992
# 2025-09-20 20:12:58,047 - root - INFO - MAE: 29.625394821166992
# INFO:root:SAE: 29.430042266845703
# 2025-09-20 20:12:58,049 - root - INFO - SAE: 29.430042266845703
# INFO:root:F1: 0.09523809523809523
# 2025-09-20 20:12:58,059 - root - INFO - F1: 0.09523809523809523
# INFO:root:Evaluate fridge:
# 2025-09-20 20:12:58,060 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 32.01982498168945
# 2025-09-20 20:12:58,062 - root - INFO - MAE: 32.01982498168945
# INFO:root:SAE: 17.155689239501953
# 2025-09-20 20:12:58,064 - root - INFO - SAE: 17.155689239501953
# INFO:root:F1: 0.7568165652414447
# 2025-09-20 20:12:58,071 - root - INFO - F1: 0.7568165652414447
# INFO:root:Evaluate microwave:
# 2025-09-20 20:12:58,073 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 26.863018035888672
# 2025-09-20 20:12:58,075 - root - INFO - MAE: 26.863018035888672
# INFO:root:SAE: 22.729488372802734
# 2025-09-20 20:12:58,076 - root - INFO - SAE: 22.729488372802734
# INFO:root:F1: 0.058666666666666666
# 2025-09-20 20:12:58,083 - root - INFO - F1: 0.058666666666666666
# INFO:root:Evaluate wash:
# 2025-09-20 20:12:58,085 - root - INFO - Evaluate wash:
# INFO:root:MAE: 30.01454734802246
# 2025-09-20 20:12:58,086 - root - INFO - MAE: 30.01454734802246
# INFO:root:SAE: 25.317550659179688
# 2025-09-20 20:12:58,088 - root - INFO - SAE: 25.317550659179688
# INFO:root:F1: 0.8604182413706223
# 2025-09-20 20:12:58,096 - root - INFO - F1: 0.8604182413706223
# INFO:root:Epoch 6, train loss: 0.039, val loss: 23136.285.
# 2025-09-20 20:12:58,098 - root - INFO - Epoch 6, train loss: 0.039, val loss: 23136.285.
# INFO:root:Early stopping overall:
# 2025-09-20 20:12:58,100 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 6 out of 30
# 2025-09-20 20:12:58,101 - root - INFO - EarlyStopping counter: 6 out of 30
# INFO:root:# of epoches: 7
# 2025-09-20 20:12:58,103 - root - INFO - # of epoches: 7
# 100%|██████████| 874/874 [16:36<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-20 20:29:34,815 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 20:29:35,139 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 29.81902503967285
# 2025-09-20 20:29:35,142 - root - INFO - MAE: 29.81902503967285
# INFO:root:SAE: 30.30387306213379
# 2025-09-20 20:29:35,143 - root - INFO - SAE: 30.30387306213379
# INFO:root:F1: 0.06794055201698514
# 2025-09-20 20:29:35,154 - root - INFO - F1: 0.06794055201698514
# INFO:root:Evaluate fridge:
# 2025-09-20 20:29:35,156 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 33.67390441894531
# 2025-09-20 20:29:35,158 - root - INFO - MAE: 33.67390441894531
# INFO:root:SAE: 18.975759506225586
# 2025-09-20 20:29:35,161 - root - INFO - SAE: 18.975759506225586
# INFO:root:F1: 0.7536571567121959
# 2025-09-20 20:29:35,169 - root - INFO - F1: 0.7536571567121959
# INFO:root:Evaluate microwave:
# 2025-09-20 20:29:35,171 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 26.136093139648438
# 2025-09-20 20:29:35,172 - root - INFO - MAE: 26.136093139648438
# INFO:root:SAE: 22.41141128540039
# 2025-09-20 20:29:35,175 - root - INFO - SAE: 22.41141128540039
# INFO:root:F1: 0.07813292744799594
# 2025-09-20 20:29:35,182 - root - INFO - F1: 0.07813292744799594
# INFO:root:Evaluate wash:
# 2025-09-20 20:29:35,184 - root - INFO - Evaluate wash:
# INFO:root:MAE: 40.58823776245117
# 2025-09-20 20:29:35,186 - root - INFO - MAE: 40.58823776245117
# INFO:root:SAE: 38.5798454284668
# 2025-09-20 20:29:35,188 - root - INFO - SAE: 38.5798454284668
# INFO:root:F1: 0.8216056828843319
# 2025-09-20 20:29:35,197 - root - INFO - F1: 0.8216056828843319
# INFO:root:Epoch 7, train loss: 0.035, val loss: 38978.938.
# 2025-09-20 20:29:35,199 - root - INFO - Epoch 7, train loss: 0.035, val loss: 38978.938.
# INFO:root:Early stopping overall:
# 2025-09-20 20:29:35,201 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 7 out of 30
# 2025-09-20 20:29:35,202 - root - INFO - EarlyStopping counter: 7 out of 30
# INFO:root:# of epoches: 8
# 2025-09-20 20:29:35,204 - root - INFO - # of epoches: 8
# 100%|██████████| 874/874 [16:36<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-20 20:46:11,422 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 20:46:11,746 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 30.597475051879883
# 2025-09-20 20:46:11,748 - root - INFO - MAE: 30.597475051879883
# INFO:root:SAE: 31.31281280517578
# 2025-09-20 20:46:11,751 - root - INFO - SAE: 31.31281280517578
# INFO:root:F1: 0.006507592190889371
# 2025-09-20 20:46:11,760 - root - INFO - F1: 0.006507592190889371
# INFO:root:Evaluate fridge:
# 2025-09-20 20:46:11,762 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 32.71204376220703
# 2025-09-20 20:46:11,764 - root - INFO - MAE: 32.71204376220703
# INFO:root:SAE: 17.87960433959961
# 2025-09-20 20:46:11,766 - root - INFO - SAE: 17.87960433959961
# INFO:root:F1: 0.7585490505671667
# 2025-09-20 20:46:11,775 - root - INFO - F1: 0.7585490505671667
# INFO:root:Evaluate microwave:
# 2025-09-20 20:46:11,780 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 28.829151153564453
# 2025-09-20 20:46:11,781 - root - INFO - MAE: 28.829151153564453
# INFO:root:SAE: 25.07988739013672
# 2025-09-20 20:46:11,783 - root - INFO - SAE: 25.07988739013672
# INFO:root:F1: 0.016701461377870562
# 2025-09-20 20:46:11,791 - root - INFO - F1: 0.016701461377870562
# INFO:root:Evaluate wash:
# 2025-09-20 20:46:11,792 - root - INFO - Evaluate wash:
# INFO:root:MAE: 25.446258544921875
# 2025-09-20 20:46:11,794 - root - INFO - MAE: 25.446258544921875
# INFO:root:SAE: 23.624095916748047
# 2025-09-20 20:46:11,795 - root - INFO - SAE: 23.624095916748047
# INFO:root:F1: 0.8393259917739153
# 2025-09-20 20:46:11,802 - root - INFO - F1: 0.8393259917739153
# INFO:root:Epoch 8, train loss: 0.031, val loss: 22336.512.
# 2025-09-20 20:46:11,804 - root - INFO - Epoch 8, train loss: 0.031, val loss: 22336.512.
# INFO:root:Early stopping overall:
# 2025-09-20 20:46:11,806 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 8 out of 30
# 2025-09-20 20:46:11,808 - root - INFO - EarlyStopping counter: 8 out of 30
# INFO:root:# of epoches: 9
# 2025-09-20 20:46:11,810 - root - INFO - # of epoches: 9
# 100%|██████████| 874/874 [16:35<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-20 21:02:47,343 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 21:02:47,669 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 31.844276428222656
# 2025-09-20 21:02:47,671 - root - INFO - MAE: 31.844276428222656
# INFO:root:SAE: 32.602081298828125
# 2025-09-20 21:02:47,673 - root - INFO - SAE: 32.602081298828125
# INFO:root:F1: 0.02553626149131767
# 2025-09-20 21:02:47,683 - root - INFO - F1: 0.02553626149131767
# INFO:root:Evaluate fridge:
# 2025-09-20 21:02:47,686 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 35.29601287841797
# 2025-09-20 21:02:47,689 - root - INFO - MAE: 35.29601287841797
# INFO:root:SAE: 21.379980087280273
# 2025-09-20 21:02:47,691 - root - INFO - SAE: 21.379980087280273
# INFO:root:F1: 0.7516974994917667
# 2025-09-20 21:02:47,700 - root - INFO - F1: 0.7516974994917667
# INFO:root:Evaluate microwave:
# 2025-09-20 21:02:47,702 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 29.773757934570312
# 2025-09-20 21:02:47,703 - root - INFO - MAE: 29.773757934570312
# INFO:root:SAE: 26.699134826660156
# 2025-09-20 21:02:47,705 - root - INFO - SAE: 26.699134826660156
# INFO:root:F1: 0.05659592176446109
# 2025-09-20 21:02:47,714 - root - INFO - F1: 0.05659592176446109
# INFO:root:Evaluate wash:
# 2025-09-20 21:02:47,715 - root - INFO - Evaluate wash:
# INFO:root:MAE: 14.879851341247559
# 2025-09-20 21:02:47,717 - root - INFO - MAE: 14.879851341247559
# INFO:root:SAE: 9.653491020202637
# 2025-09-20 21:02:47,720 - root - INFO - SAE: 9.653491020202637
# INFO:root:F1: 0.9277355531427193
# 2025-09-20 21:02:47,728 - root - INFO - F1: 0.9277355531427193
# INFO:root:Epoch 9, train loss: 0.029, val loss: 15222.619.
# 2025-09-20 21:02:47,731 - root - INFO - Epoch 9, train loss: 0.029, val loss: 15222.619.
# INFO:root:Early stopping overall:
# 2025-09-20 21:02:47,732 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 9 out of 30
# 2025-09-20 21:02:47,733 - root - INFO - EarlyStopping counter: 9 out of 30
# INFO:root:# of epoches: 10
# 2025-09-20 21:02:47,735 - root - INFO - # of epoches: 10
# 100%|██████████| 874/874 [16:36<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-20 21:19:24,342 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 21:19:24,763 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 29.398998260498047
# 2025-09-20 21:19:24,767 - root - INFO - MAE: 29.398998260498047
# INFO:root:SAE: 30.106929779052734
# 2025-09-20 21:19:24,772 - root - INFO - SAE: 30.106929779052734
# INFO:root:F1: 0.0024096385542168677
# 2025-09-20 21:19:24,781 - root - INFO - F1: 0.0024096385542168677
# INFO:root:Evaluate fridge:
# 2025-09-20 21:19:24,784 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 36.25129699707031
# 2025-09-20 21:19:24,785 - root - INFO - MAE: 36.25129699707031
# INFO:root:SAE: 24.188562393188477
# 2025-09-20 21:19:24,788 - root - INFO - SAE: 24.188562393188477
# INFO:root:F1: 0.7740746549560853
# 2025-09-20 21:19:24,796 - root - INFO - F1: 0.7740746549560853
# INFO:root:Evaluate microwave:
# 2025-09-20 21:19:24,798 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 28.792627334594727
# 2025-09-20 21:19:24,800 - root - INFO - MAE: 28.792627334594727
# INFO:root:SAE: 22.742212295532227
# 2025-09-20 21:19:24,801 - root - INFO - SAE: 22.742212295532227
# INFO:root:F1: 0.05343511450381679
# 2025-09-20 21:19:24,810 - root - INFO - F1: 0.05343511450381679
# INFO:root:Evaluate wash:
# 2025-09-20 21:19:24,812 - root - INFO - Evaluate wash:
# INFO:root:MAE: 18.69825553894043
# 2025-09-20 21:19:24,814 - root - INFO - MAE: 18.69825553894043
# INFO:root:SAE: 11.112427711486816
# 2025-09-20 21:19:24,816 - root - INFO - SAE: 11.112427711486816
# INFO:root:F1: 0.9322111010009099
# 2025-09-20 21:19:24,824 - root - INFO - F1: 0.9322111010009099
# INFO:root:Epoch 10, train loss: 0.027, val loss: 21086.689.
# 2025-09-20 21:19:24,826 - root - INFO - Epoch 10, train loss: 0.027, val loss: 21086.689.
# INFO:root:Model saved
# 2025-09-20 21:19:25,001 - root - INFO - Model saved
# INFO:root:Early stopping overall:
# 2025-09-20 21:19:25,007 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 10 out of 30
# 2025-09-20 21:19:25,009 - root - INFO - EarlyStopping counter: 10 out of 30
# INFO:root:# of epoches: 11
# 2025-09-20 21:19:25,011 - root - INFO - # of epoches: 11
# 100%|██████████| 874/874 [16:30<00:00,  1.13s/it]
# INFO:root:Validation:
# 2025-09-20 21:35:56,011 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 21:35:56,336 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 30.025217056274414
# 2025-09-20 21:35:56,339 - root - INFO - MAE: 30.025217056274414
# INFO:root:SAE: 30.633623123168945
# 2025-09-20 21:35:56,341 - root - INFO - SAE: 30.633623123168945
# INFO:root:F1: 0.009259259259259259
# 2025-09-20 21:35:56,355 - root - INFO - F1: 0.009259259259259259
# INFO:root:Evaluate fridge:
# 2025-09-20 21:35:56,357 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 34.0819091796875
# 2025-09-20 21:35:56,359 - root - INFO - MAE: 34.0819091796875
# INFO:root:SAE: 21.438894271850586
# 2025-09-20 21:35:56,361 - root - INFO - SAE: 21.438894271850586
# INFO:root:F1: 0.7702605785321539
# 2025-09-20 21:35:56,373 - root - INFO - F1: 0.7702605785321539
# INFO:root:Evaluate microwave:
# 2025-09-20 21:35:56,375 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 28.261327743530273
# 2025-09-20 21:35:56,377 - root - INFO - MAE: 28.261327743530273
# INFO:root:SAE: 26.04093360900879
# 2025-09-20 21:35:56,380 - root - INFO - SAE: 26.04093360900879
# INFO:root:F1: 0.0700955848884843
# 2025-09-20 21:35:56,387 - root - INFO - F1: 0.0700955848884843
# INFO:root:Evaluate wash:
# 2025-09-20 21:35:56,390 - root - INFO - Evaluate wash:
# INFO:root:MAE: 17.06267738342285
# 2025-09-20 21:35:56,392 - root - INFO - MAE: 17.06267738342285
# INFO:root:SAE: 10.989866256713867
# 2025-09-20 21:35:56,394 - root - INFO - SAE: 10.989866256713867
# INFO:root:F1: 0.9321956769055745
# 2025-09-20 21:35:56,404 - root - INFO - F1: 0.9321956769055745
# INFO:root:Epoch 11, train loss: 0.025, val loss: 17390.717.
# 2025-09-20 21:35:56,407 - root - INFO - Epoch 11, train loss: 0.025, val loss: 17390.717.
# INFO:root:Early stopping overall:
# 2025-09-20 21:35:56,408 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 11 out of 30
# 2025-09-20 21:35:56,410 - root - INFO - EarlyStopping counter: 11 out of 30
# INFO:root:# of epoches: 12
# 2025-09-20 21:35:56,411 - root - INFO - # of epoches: 12
# 100%|██████████| 874/874 [16:49<00:00,  1.15s/it]
# INFO:root:Validation:
# 2025-09-20 21:52:45,541 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 21:52:45,903 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 29.979204177856445
# 2025-09-20 21:52:45,909 - root - INFO - MAE: 29.979204177856445
# INFO:root:SAE: 30.643861770629883
# 2025-09-20 21:52:45,911 - root - INFO - SAE: 30.643861770629883
# INFO:root:F1: 0.0
# 2025-09-20 21:52:45,922 - root - INFO - F1: 0.0
# INFO:root:Evaluate fridge:
# 2025-09-20 21:52:45,924 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 35.20694351196289
# 2025-09-20 21:52:45,926 - root - INFO - MAE: 35.20694351196289
# INFO:root:SAE: 20.48746681213379
# 2025-09-20 21:52:45,928 - root - INFO - SAE: 20.48746681213379
# INFO:root:F1: 0.7244081957429879
# 2025-09-20 21:52:45,936 - root - INFO - F1: 0.7244081957429879
# INFO:root:Evaluate microwave:
# 2025-09-20 21:52:45,938 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 27.55371856689453
# 2025-09-20 21:52:45,940 - root - INFO - MAE: 27.55371856689453
# INFO:root:SAE: 22.199155807495117
# 2025-09-20 21:52:45,942 - root - INFO - SAE: 22.199155807495117
# INFO:root:F1: 0.03927813163481953
# 2025-09-20 21:52:45,952 - root - INFO - F1: 0.03927813163481953
# INFO:root:Evaluate wash:
# 2025-09-20 21:52:45,954 - root - INFO - Evaluate wash:
# INFO:root:MAE: 13.867795944213867
# 2025-09-20 21:52:45,955 - root - INFO - MAE: 13.867795944213867
# INFO:root:SAE: 7.9687700271606445
# 2025-09-20 21:52:45,958 - root - INFO - SAE: 7.9687700271606445
# INFO:root:F1: 0.9342241677226126
# 2025-09-20 21:52:45,965 - root - INFO - F1: 0.9342241677226126
# INFO:root:Epoch 12, train loss: 0.024, val loss: 13925.022.
# 2025-09-20 21:52:45,968 - root - INFO - Epoch 12, train loss: 0.024, val loss: 13925.022.
# INFO:root:Early stopping overall:
# 2025-09-20 21:52:45,969 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 12 out of 30
# 2025-09-20 21:52:45,971 - root - INFO - EarlyStopping counter: 12 out of 30
# INFO:root:# of epoches: 13
# 2025-09-20 21:52:45,973 - root - INFO - # of epoches: 13
# 100%|██████████| 874/874 [16:31<00:00,  1.13s/it]
# INFO:root:Validation:
# 2025-09-20 22:09:17,175 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 22:09:17,498 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 31.93112564086914
# 2025-09-20 22:09:17,501 - root - INFO - MAE: 31.93112564086914
# INFO:root:SAE: 32.66632080078125
# 2025-09-20 22:09:17,502 - root - INFO - SAE: 32.66632080078125
# INFO:root:F1: 0.0
# 2025-09-20 22:09:17,510 - root - INFO - F1: 0.0
# INFO:root:Evaluate fridge:
# 2025-09-20 22:09:17,512 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 37.9139404296875
# 2025-09-20 22:09:17,513 - root - INFO - MAE: 37.9139404296875
# INFO:root:SAE: 24.374134063720703
# 2025-09-20 22:09:17,515 - root - INFO - SAE: 24.374134063720703
# INFO:root:F1: 0.7417017017017017
# 2025-09-20 22:09:17,522 - root - INFO - F1: 0.7417017017017017
# INFO:root:Evaluate microwave:
# 2025-09-20 22:09:17,523 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 25.8048152923584
# 2025-09-20 22:09:17,525 - root - INFO - MAE: 25.8048152923584
# INFO:root:SAE: 23.09648323059082
# 2025-09-20 22:09:17,527 - root - INFO - SAE: 23.09648323059082
# INFO:root:F1: 0.05770277626565052
# 2025-09-20 22:09:17,536 - root - INFO - F1: 0.05770277626565052
# INFO:root:Evaluate wash:
# 2025-09-20 22:09:17,537 - root - INFO - Evaluate wash:
# INFO:root:MAE: 16.197359085083008
# 2025-09-20 22:09:17,539 - root - INFO - MAE: 16.197359085083008
# INFO:root:SAE: 10.68917465209961
# 2025-09-20 22:09:17,541 - root - INFO - SAE: 10.68917465209961
# INFO:root:F1: 0.9293208808947307
# 2025-09-20 22:09:17,549 - root - INFO - F1: 0.9293208808947307
# INFO:root:Epoch 13, train loss: 0.022, val loss: 14936.581.
# 2025-09-20 22:09:17,553 - root - INFO - Epoch 13, train loss: 0.022, val loss: 14936.581.
# INFO:root:Early stopping overall:
# 2025-09-20 22:09:17,555 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 13 out of 30
# 2025-09-20 22:09:17,556 - root - INFO - EarlyStopping counter: 13 out of 30
# INFO:root:# of epoches: 14
# 2025-09-20 22:09:17,557 - root - INFO - # of epoches: 14
# 100%|██████████| 874/874 [16:32<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-20 22:25:49,608 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 22:25:49,939 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 32.84174728393555
# 2025-09-20 22:25:49,941 - root - INFO - MAE: 32.84174728393555
# INFO:root:SAE: 33.59418869018555
# 2025-09-20 22:25:49,943 - root - INFO - SAE: 33.59418869018555
# INFO:root:F1: 0.010764262648008612
# 2025-09-20 22:25:49,954 - root - INFO - F1: 0.010764262648008612
# INFO:root:Evaluate fridge:
# 2025-09-20 22:25:49,955 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 36.8464469909668
# 2025-09-20 22:25:49,957 - root - INFO - MAE: 36.8464469909668
# INFO:root:SAE: 17.669404983520508
# 2025-09-20 22:25:49,959 - root - INFO - SAE: 17.669404983520508
# INFO:root:F1: 0.71125300605357
# 2025-09-20 22:25:49,966 - root - INFO - F1: 0.71125300605357
# INFO:root:Evaluate microwave:
# 2025-09-20 22:25:49,968 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 27.655269622802734
# 2025-09-20 22:25:49,970 - root - INFO - MAE: 27.655269622802734
# INFO:root:SAE: 25.126548767089844
# 2025-09-20 22:25:49,972 - root - INFO - SAE: 25.126548767089844
# INFO:root:F1: 0.0011968880909634949
# 2025-09-20 22:25:49,979 - root - INFO - F1: 0.0011968880909634949
# INFO:root:Evaluate wash:
# 2025-09-20 22:25:49,981 - root - INFO - Evaluate wash:
# INFO:root:MAE: 18.514787673950195
# 2025-09-20 22:25:49,982 - root - INFO - MAE: 18.514787673950195
# INFO:root:SAE: 13.41733455657959
# 2025-09-20 22:25:49,984 - root - INFO - SAE: 13.41733455657959
# INFO:root:F1: 0.8963855421686747
# 2025-09-20 22:25:49,991 - root - INFO - F1: 0.8963855421686747
# INFO:root:Epoch 14, train loss: 0.021, val loss: 18376.871.
# 2025-09-20 22:25:49,993 - root - INFO - Epoch 14, train loss: 0.021, val loss: 18376.871.
# INFO:root:Early stopping overall:
# 2025-09-20 22:25:49,995 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 14 out of 30
# 2025-09-20 22:25:49,996 - root - INFO - EarlyStopping counter: 14 out of 30
# INFO:root:# of epoches: 15
# 2025-09-20 22:25:49,998 - root - INFO - # of epoches: 15
# 100%|██████████| 874/874 [16:31<00:00,  1.13s/it]
# INFO:root:Validation:
# 2025-09-20 22:42:21,109 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 22:42:21,465 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 33.9203987121582
# 2025-09-20 22:42:21,470 - root - INFO - MAE: 33.9203987121582
# INFO:root:SAE: 30.404008865356445
# 2025-09-20 22:42:21,472 - root - INFO - SAE: 30.404008865356445
# INFO:root:F1: 0.12244897959183673
# 2025-09-20 22:42:21,480 - root - INFO - F1: 0.12244897959183673
# INFO:root:Evaluate fridge:
# 2025-09-20 22:42:21,482 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 34.790557861328125
# 2025-09-20 22:42:21,484 - root - INFO - MAE: 34.790557861328125
# INFO:root:SAE: 23.293367385864258
# 2025-09-20 22:42:21,487 - root - INFO - SAE: 23.293367385864258
# INFO:root:F1: 0.7611619578193395
# 2025-09-20 22:42:21,503 - root - INFO - F1: 0.7611619578193395
# INFO:root:Evaluate microwave:
# 2025-09-20 22:42:21,504 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 30.327110290527344
# 2025-09-20 22:42:21,506 - root - INFO - MAE: 30.327110290527344
# INFO:root:SAE: 24.69078826904297
# 2025-09-20 22:42:21,508 - root - INFO - SAE: 24.69078826904297
# INFO:root:F1: 0.002806361085126286
# 2025-09-20 22:42:21,515 - root - INFO - F1: 0.002806361085126286
# INFO:root:Evaluate wash:
# 2025-09-20 22:42:21,520 - root - INFO - Evaluate wash:
# INFO:root:MAE: 12.90353012084961
# 2025-09-20 22:42:21,522 - root - INFO - MAE: 12.90353012084961
# INFO:root:SAE: 7.065396308898926
# 2025-09-20 22:42:21,524 - root - INFO - SAE: 7.065396308898926
# INFO:root:F1: 0.9312686122692079
# 2025-09-20 22:42:21,534 - root - INFO - F1: 0.9312686122692079
# INFO:root:Epoch 15, train loss: 0.020, val loss: 15486.909.
# 2025-09-20 22:42:21,536 - root - INFO - Epoch 15, train loss: 0.020, val loss: 15486.909.
# INFO:root:Early stopping overall:
# 2025-09-20 22:42:21,541 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 15 out of 30
# 2025-09-20 22:42:21,543 - root - INFO - EarlyStopping counter: 15 out of 30
# INFO:root:# of epoches: 16
# 2025-09-20 22:42:21,544 - root - INFO - # of epoches: 16
# 100%|██████████| 874/874 [16:30<00:00,  1.13s/it]
# INFO:root:Validation:
# 2025-09-20 22:58:52,480 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 22:58:52,805 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 31.670785903930664
# 2025-09-20 22:58:52,807 - root - INFO - MAE: 31.670785903930664
# INFO:root:SAE: 32.43436050415039
# 2025-09-20 22:58:52,809 - root - INFO - SAE: 32.43436050415039
# INFO:root:F1: 0.0
# 2025-09-20 22:58:52,818 - root - INFO - F1: 0.0
# INFO:root:Evaluate fridge:
# 2025-09-20 22:58:52,820 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 38.25168228149414
# 2025-09-20 22:58:52,822 - root - INFO - MAE: 38.25168228149414
# INFO:root:SAE: 24.1943359375
# 2025-09-20 22:58:52,824 - root - INFO - SAE: 24.1943359375
# INFO:root:F1: 0.7388915432393693
# 2025-09-20 22:58:52,831 - root - INFO - F1: 0.7388915432393693
# INFO:root:Evaluate microwave:
# 2025-09-20 22:58:52,833 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 29.46017074584961
# 2025-09-20 22:58:52,835 - root - INFO - MAE: 29.46017074584961
# INFO:root:SAE: 23.747541427612305
# 2025-09-20 22:58:52,837 - root - INFO - SAE: 23.747541427612305
# INFO:root:F1: 0.005211047420531527
# 2025-09-20 22:58:52,844 - root - INFO - F1: 0.005211047420531527
# INFO:root:Evaluate wash:
# 2025-09-20 22:58:52,845 - root - INFO - Evaluate wash:
# INFO:root:MAE: 10.915422439575195
# 2025-09-20 22:58:52,847 - root - INFO - MAE: 10.915422439575195
# INFO:root:SAE: 5.77448844909668
# 2025-09-20 22:58:52,849 - root - INFO - SAE: 5.77448844909668
# INFO:root:F1: 0.9403229581090569
# 2025-09-20 22:58:52,856 - root - INFO - F1: 0.9403229581090569
# INFO:root:Epoch 16, train loss: 0.019, val loss: 15315.427.
# 2025-09-20 22:58:52,858 - root - INFO - Epoch 16, train loss: 0.019, val loss: 15315.427.
# INFO:root:Early stopping overall:
# 2025-09-20 22:58:52,860 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 16 out of 30
# 2025-09-20 22:58:52,862 - root - INFO - EarlyStopping counter: 16 out of 30
# INFO:root:# of epoches: 17
# 2025-09-20 22:58:52,863 - root - INFO - # of epoches: 17
# 100%|██████████| 874/874 [16:31<00:00,  1.13s/it]
# INFO:root:Validation:
# 2025-09-20 23:15:24,354 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 23:15:24,678 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 28.3034725189209
# 2025-09-20 23:15:24,681 - root - INFO - MAE: 28.3034725189209
# INFO:root:SAE: 28.981290817260742
# 2025-09-20 23:15:24,687 - root - INFO - SAE: 28.981290817260742
# INFO:root:F1: 0.0
# 2025-09-20 23:15:24,697 - root - INFO - F1: 0.0
# INFO:root:Evaluate fridge:
# 2025-09-20 23:15:24,699 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 35.63969039916992
# 2025-09-20 23:15:24,701 - root - INFO - MAE: 35.63969039916992
# INFO:root:SAE: 15.517159461975098
# 2025-09-20 23:15:24,703 - root - INFO - SAE: 15.517159461975098
# INFO:root:F1: 0.7353873859765885
# 2025-09-20 23:15:24,713 - root - INFO - F1: 0.7353873859765885
# INFO:root:Evaluate microwave:
# 2025-09-20 23:15:24,714 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 28.506107330322266
# 2025-09-20 23:15:24,716 - root - INFO - MAE: 28.506107330322266
# INFO:root:SAE: 20.651329040527344
# 2025-09-20 23:15:24,718 - root - INFO - SAE: 20.651329040527344
# INFO:root:F1: 0.04169468728984533
# 2025-09-20 23:15:24,728 - root - INFO - F1: 0.04169468728984533
# INFO:root:Evaluate wash:
# 2025-09-20 23:15:24,730 - root - INFO - Evaluate wash:
# INFO:root:MAE: 40.56884765625
# 2025-09-20 23:15:24,731 - root - INFO - MAE: 40.56884765625
# INFO:root:SAE: 25.1890811920166
# 2025-09-20 23:15:24,733 - root - INFO - SAE: 25.1890811920166
# INFO:root:F1: 0.9227867499705293
# 2025-09-20 23:15:24,740 - root - INFO - F1: 0.9227867499705293
# INFO:root:Epoch 17, train loss: 0.018, val loss: 29291.305.
# 2025-09-20 23:15:24,742 - root - INFO - Epoch 17, train loss: 0.018, val loss: 29291.305.
# INFO:root:Early stopping overall:
# 2025-09-20 23:15:24,743 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 17 out of 30
# 2025-09-20 23:15:24,745 - root - INFO - EarlyStopping counter: 17 out of 30
# INFO:root:# of epoches: 18
# 2025-09-20 23:15:24,747 - root - INFO - # of epoches: 18
# 100%|██████████| 874/874 [16:30<00:00,  1.13s/it]
# INFO:root:Validation:
# 2025-09-20 23:31:55,535 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 23:31:55,904 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 31.62042808532715
# 2025-09-20 23:31:55,909 - root - INFO - MAE: 31.62042808532715
# INFO:root:SAE: 29.28665542602539
# 2025-09-20 23:31:55,911 - root - INFO - SAE: 29.28665542602539
# INFO:root:F1: 0.13796296296296295
# 2025-09-20 23:31:55,922 - root - INFO - F1: 0.13796296296296295
# INFO:root:Evaluate fridge:
# 2025-09-20 23:31:55,924 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 38.570743560791016
# 2025-09-20 23:31:55,925 - root - INFO - MAE: 38.570743560791016
# INFO:root:SAE: 23.416606903076172
# 2025-09-20 23:31:55,927 - root - INFO - SAE: 23.416606903076172
# INFO:root:F1: 0.7403314917127072
# 2025-09-20 23:31:55,935 - root - INFO - F1: 0.7403314917127072
# INFO:root:Evaluate microwave:
# 2025-09-20 23:31:55,937 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 27.566286087036133
# 2025-09-20 23:31:55,939 - root - INFO - MAE: 27.566286087036133
# INFO:root:SAE: 24.1085147857666
# 2025-09-20 23:31:55,941 - root - INFO - SAE: 24.1085147857666
# INFO:root:F1: 0.018292682926829267
# 2025-09-20 23:31:55,949 - root - INFO - F1: 0.018292682926829267
# INFO:root:Evaluate wash:
# 2025-09-20 23:31:55,951 - root - INFO - Evaluate wash:
# INFO:root:MAE: 11.90335464477539
# 2025-09-20 23:31:55,952 - root - INFO - MAE: 11.90335464477539
# INFO:root:SAE: 7.254950523376465
# 2025-09-20 23:31:55,954 - root - INFO - SAE: 7.254950523376465
# INFO:root:F1: 0.9478383458646616
# 2025-09-20 23:31:55,961 - root - INFO - F1: 0.9478383458646616
# INFO:root:Epoch 18, train loss: 0.018, val loss: 15068.318.
# 2025-09-20 23:31:55,963 - root - INFO - Epoch 18, train loss: 0.018, val loss: 15068.318.
# INFO:root:Early stopping overall:
# 2025-09-20 23:31:55,964 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 18 out of 30
# 2025-09-20 23:31:55,965 - root - INFO - EarlyStopping counter: 18 out of 30
# INFO:root:# of epoches: 19
# 2025-09-20 23:31:55,967 - root - INFO - # of epoches: 19
# 100%|██████████| 874/874 [16:31<00:00,  1.13s/it]
# INFO:root:Validation:
# 2025-09-20 23:48:27,931 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-20 23:48:28,268 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 27.60782241821289
# 2025-09-20 23:48:28,270 - root - INFO - MAE: 27.60782241821289
# INFO:root:SAE: 23.178272247314453
# 2025-09-20 23:48:28,272 - root - INFO - SAE: 23.178272247314453
# INFO:root:F1: 0.2942708333333333
# 2025-09-20 23:48:28,281 - root - INFO - F1: 0.2942708333333333
# INFO:root:Evaluate fridge:
# 2025-09-20 23:48:28,282 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 38.381221771240234
# 2025-09-20 23:48:28,284 - root - INFO - MAE: 38.381221771240234
# INFO:root:SAE: 22.341184616088867
# 2025-09-20 23:48:28,286 - root - INFO - SAE: 22.341184616088867
# INFO:root:F1: 0.7417039255096599
# 2025-09-20 23:48:28,294 - root - INFO - F1: 0.7417039255096599
# INFO:root:Evaluate microwave:
# 2025-09-20 23:48:28,300 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 27.41984748840332
# 2025-09-20 23:48:28,302 - root - INFO - MAE: 27.41984748840332
# INFO:root:SAE: 23.227481842041016
# 2025-09-20 23:48:28,304 - root - INFO - SAE: 23.227481842041016
# INFO:root:F1: 0.01844532279314888
# 2025-09-20 23:48:28,311 - root - INFO - F1: 0.01844532279314888
# INFO:root:Evaluate wash:
# 2025-09-20 23:48:28,316 - root - INFO - Evaluate wash:
# INFO:root:MAE: 12.669891357421875
# 2025-09-20 23:48:28,318 - root - INFO - MAE: 12.669891357421875
# INFO:root:SAE: 8.618097305297852
# 2025-09-20 23:48:28,320 - root - INFO - SAE: 8.618097305297852
# INFO:root:F1: 0.9488503050211169
# 2025-09-20 23:48:28,327 - root - INFO - F1: 0.9488503050211169
# INFO:root:Epoch 19, train loss: 0.018, val loss: 16466.844.
# 2025-09-20 23:48:28,331 - root - INFO - Epoch 19, train loss: 0.018, val loss: 16466.844.
# INFO:root:Early stopping overall:
# 2025-09-20 23:48:28,333 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 19 out of 30
# 2025-09-20 23:48:28,334 - root - INFO - EarlyStopping counter: 19 out of 30
# INFO:root:# of epoches: 20
# 2025-09-20 23:48:28,335 - root - INFO - # of epoches: 20
# 100%|██████████| 874/874 [16:34<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-21 00:05:02,568 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-21 00:05:02,892 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 34.77181625366211
# 2025-09-21 00:05:02,896 - root - INFO - MAE: 34.77181625366211
# INFO:root:SAE: 24.649194717407227
# 2025-09-21 00:05:02,899 - root - INFO - SAE: 24.649194717407227
# INFO:root:F1: 0.33368532206969376
# 2025-09-21 00:05:02,911 - root - INFO - F1: 0.33368532206969376
# INFO:root:Evaluate fridge:
# 2025-09-21 00:05:02,912 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 35.369747161865234
# 2025-09-21 00:05:02,916 - root - INFO - MAE: 35.369747161865234
# INFO:root:SAE: 19.366445541381836
# 2025-09-21 00:05:02,918 - root - INFO - SAE: 19.366445541381836
# INFO:root:F1: 0.7544832611423714
# 2025-09-21 00:05:02,925 - root - INFO - F1: 0.7544832611423714
# INFO:root:Evaluate microwave:
# 2025-09-21 00:05:02,926 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 27.622695922851562
# 2025-09-21 00:05:02,928 - root - INFO - MAE: 27.622695922851562
# INFO:root:SAE: 25.56363296508789
# 2025-09-21 00:05:02,932 - root - INFO - SAE: 25.56363296508789
# INFO:root:F1: 0.022197558268590455
# 2025-09-21 00:05:02,938 - root - INFO - F1: 0.022197558268590455
# INFO:root:Evaluate wash:
# 2025-09-21 00:05:02,940 - root - INFO - Evaluate wash:
# INFO:root:MAE: 11.210541725158691
# 2025-09-21 00:05:02,942 - root - INFO - MAE: 11.210541725158691
# INFO:root:SAE: 6.350889205932617
# 2025-09-21 00:05:02,944 - root - INFO - SAE: 6.350889205932617
# INFO:root:F1: 0.9410786410073652
# 2025-09-21 00:05:02,951 - root - INFO - F1: 0.9410786410073652
# INFO:root:Epoch 20, train loss: 0.017, val loss: 15090.593.
# 2025-09-21 00:05:02,953 - root - INFO - Epoch 20, train loss: 0.017, val loss: 15090.593.
# INFO:root:Model saved
# 2025-09-21 00:05:03,107 - root - INFO - Model saved
# INFO:root:Early stopping overall:
# 2025-09-21 00:05:03,110 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 20 out of 30
# 2025-09-21 00:05:03,114 - root - INFO - EarlyStopping counter: 20 out of 30
# INFO:root:# of epoches: 21
# 2025-09-21 00:05:03,115 - root - INFO - # of epoches: 21
# 100%|██████████| 874/874 [16:31<00:00,  1.13s/it]
# INFO:root:Validation:
# 2025-09-21 00:21:34,901 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-21 00:21:35,229 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 31.688106536865234
# 2025-09-21 00:21:35,231 - root - INFO - MAE: 31.688106536865234
# INFO:root:SAE: 20.271577835083008
# 2025-09-21 00:21:35,233 - root - INFO - SAE: 20.271577835083008
# INFO:root:F1: 0.3857943925233645
# 2025-09-21 00:21:35,242 - root - INFO - F1: 0.3857943925233645
# INFO:root:Evaluate fridge:
# 2025-09-21 00:21:35,243 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 37.95124053955078
# 2025-09-21 00:21:35,245 - root - INFO - MAE: 37.95124053955078
# INFO:root:SAE: 23.431751251220703
# 2025-09-21 00:21:35,247 - root - INFO - SAE: 23.431751251220703
# INFO:root:F1: 0.738628594409813
# 2025-09-21 00:21:35,254 - root - INFO - F1: 0.738628594409813
# INFO:root:Evaluate microwave:
# 2025-09-21 00:21:35,256 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 27.01433753967285
# 2025-09-21 00:21:35,258 - root - INFO - MAE: 27.01433753967285
# INFO:root:SAE: 24.379104614257812
# 2025-09-21 00:21:35,259 - root - INFO - SAE: 24.379104614257812
# INFO:root:F1: 0.01931200965600483
# 2025-09-21 00:21:35,271 - root - INFO - F1: 0.01931200965600483
# INFO:root:Evaluate wash:
# 2025-09-21 00:21:35,277 - root - INFO - Evaluate wash:
# INFO:root:MAE: 12.48847770690918
# 2025-09-21 00:21:35,279 - root - INFO - MAE: 12.48847770690918
# INFO:root:SAE: 9.142990112304688
# 2025-09-21 00:21:35,281 - root - INFO - SAE: 9.142990112304688
# INFO:root:F1: 0.9268817204301075
# 2025-09-21 00:21:35,290 - root - INFO - F1: 0.9268817204301075
# INFO:root:Epoch 21, train loss: 0.016, val loss: 15172.024.
# 2025-09-21 00:21:35,292 - root - INFO - Epoch 21, train loss: 0.016, val loss: 15172.024.
# INFO:root:Early stopping overall:
# 2025-09-21 00:21:35,294 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 21 out of 30
# 2025-09-21 00:21:35,295 - root - INFO - EarlyStopping counter: 21 out of 30
# INFO:root:# of epoches: 22
# 2025-09-21 00:21:35,297 - root - INFO - # of epoches: 22
# 100%|██████████| 874/874 [16:31<00:00,  1.13s/it]
# INFO:root:Validation:
# 2025-09-21 00:38:06,907 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# ...
# 2025-09-21 09:29:31,098 - root - INFO - # of epoches: 55
# 100%|██████████| 874/874 [16:33<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-21 09:46:04,660 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-21 09:46:04,988 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 32.593406677246094
# 2025-09-21 09:46:04,990 - root - INFO - MAE: 32.593406677246094
# INFO:root:SAE: 28.15129280090332
# 2025-09-21 09:46:04,992 - root - INFO - SAE: 28.15129280090332
# INFO:root:F1: 0.13749434644957034
# 2025-09-21 09:46:05,000 - root - INFO - F1: 0.13749434644957034
# INFO:root:Evaluate fridge:
# 2025-09-21 09:46:05,001 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 39.06267166137695
# 2025-09-21 09:46:05,003 - root - INFO - MAE: 39.06267166137695
# INFO:root:SAE: 22.784814834594727
# 2025-09-21 09:46:05,005 - root - INFO - SAE: 22.784814834594727
# INFO:root:F1: 0.7322747867259888
# 2025-09-21 09:46:05,012 - root - INFO - F1: 0.7322747867259888
# INFO:root:Evaluate microwave:
# 2025-09-21 09:46:05,013 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 24.409528732299805
# 2025-09-21 09:46:05,014 - root - INFO - MAE: 24.409528732299805
# INFO:root:SAE: 19.472192764282227
# 2025-09-21 09:46:05,016 - root - INFO - SAE: 19.472192764282227
# INFO:root:F1: 0.12430347192456065
# 2025-09-21 09:46:05,023 - root - INFO - F1: 0.12430347192456065
# INFO:root:Evaluate wash:
# 2025-09-21 09:46:05,024 - root - INFO - Evaluate wash:
# INFO:root:MAE: 16.222761154174805
# 2025-09-21 09:46:05,026 - root - INFO - MAE: 16.222761154174805
# INFO:root:SAE: 10.273297309875488
# 2025-09-21 09:46:05,028 - root - INFO - SAE: 10.273297309875488
# INFO:root:F1: 0.922226144252265
# 2025-09-21 09:46:05,035 - root - INFO - F1: 0.922226144252265
# INFO:root:Epoch 55, train loss: 0.007, val loss: 17105.408.
# 2025-09-21 09:46:05,036 - root - INFO - Epoch 55, train loss: 0.007, val loss: 17105.408.
# INFO:root:Early stopping overall:
# 2025-09-21 09:46:05,038 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 25 out of 30
# 2025-09-21 09:46:05,039 - root - INFO - EarlyStopping counter: 25 out of 30
# INFO:root:# of epoches: 56
# 2025-09-21 09:46:05,040 - root - INFO - # of epoches: 56
# 100%|██████████| 874/874 [16:34<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-21 10:02:39,246 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-21 10:02:39,635 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 32.32471466064453
# 2025-09-21 10:02:39,638 - root - INFO - MAE: 32.32471466064453
# INFO:root:SAE: 27.06159782409668
# 2025-09-21 10:02:39,640 - root - INFO - SAE: 27.06159782409668
# INFO:root:F1: 0.19068736141906872
# 2025-09-21 10:02:39,657 - root - INFO - F1: 0.19068736141906872
# INFO:root:Evaluate fridge:
# 2025-09-21 10:02:39,658 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 40.13917922973633
# 2025-09-21 10:02:39,660 - root - INFO - MAE: 40.13917922973633
# INFO:root:SAE: 23.61113929748535
# 2025-09-21 10:02:39,662 - root - INFO - SAE: 23.61113929748535
# INFO:root:F1: 0.7339943689558085
# 2025-09-21 10:02:39,672 - root - INFO - F1: 0.7339943689558085
# INFO:root:Evaluate microwave:
# 2025-09-21 10:02:39,675 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 24.46658706665039
# 2025-09-21 10:02:39,677 - root - INFO - MAE: 24.46658706665039
# INFO:root:SAE: 19.628957748413086
# 2025-09-21 10:02:39,680 - root - INFO - SAE: 19.628957748413086
# INFO:root:F1: 0.10664172123479888
# 2025-09-21 10:02:39,688 - root - INFO - F1: 0.10664172123479888
# INFO:root:Evaluate wash:
# 2025-09-21 10:02:39,691 - root - INFO - Evaluate wash:
# INFO:root:MAE: 14.772937774658203
# 2025-09-21 10:02:39,692 - root - INFO - MAE: 14.772937774658203
# INFO:root:SAE: 9.116096496582031
# 2025-09-21 10:02:39,695 - root - INFO - SAE: 9.116096496582031
# INFO:root:F1: 0.930565329580108
# 2025-09-21 10:02:39,704 - root - INFO - F1: 0.930565329580108
# INFO:root:Epoch 56, train loss: 0.007, val loss: 16934.469.
# 2025-09-21 10:02:39,708 - root - INFO - Epoch 56, train loss: 0.007, val loss: 16934.469.
# INFO:root:Early stopping overall:
# 2025-09-21 10:02:39,709 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 26 out of 30
# 2025-09-21 10:02:39,712 - root - INFO - EarlyStopping counter: 26 out of 30
# INFO:root:# of epoches: 57
# 2025-09-21 10:02:39,713 - root - INFO - # of epoches: 57
# 100%|██████████| 874/874 [16:34<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-21 10:19:14,343 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-21 10:19:14,720 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 26.362977981567383
# 2025-09-21 10:19:14,724 - root - INFO - MAE: 26.362977981567383
# INFO:root:SAE: 16.29775047302246
# 2025-09-21 10:19:14,727 - root - INFO - SAE: 16.29775047302246
# INFO:root:F1: 0.4451240231056745
# 2025-09-21 10:19:14,740 - root - INFO - F1: 0.4451240231056745
# INFO:root:Evaluate fridge:
# 2025-09-21 10:19:14,741 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 39.12260437011719
# 2025-09-21 10:19:14,743 - root - INFO - MAE: 39.12260437011719
# INFO:root:SAE: 21.44131851196289
# 2025-09-21 10:19:14,747 - root - INFO - SAE: 21.44131851196289
# INFO:root:F1: 0.7261475409836066
# 2025-09-21 10:19:14,754 - root - INFO - F1: 0.7261475409836066
# INFO:root:Evaluate microwave:
# 2025-09-21 10:19:14,755 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 27.375091552734375
# 2025-09-21 10:19:14,757 - root - INFO - MAE: 27.375091552734375
# INFO:root:SAE: 20.11062240600586
# 2025-09-21 10:19:14,758 - root - INFO - SAE: 20.11062240600586
# INFO:root:F1: 0.12487611496531219
# 2025-09-21 10:19:14,764 - root - INFO - F1: 0.12487611496531219
# INFO:root:Evaluate wash:
# 2025-09-21 10:19:14,766 - root - INFO - Evaluate wash:
# INFO:root:MAE: 14.802617073059082
# 2025-09-21 10:19:14,767 - root - INFO - MAE: 14.802617073059082
# INFO:root:SAE: 11.91994571685791
# 2025-09-21 10:19:14,769 - root - INFO - SAE: 11.91994571685791
# INFO:root:F1: 0.9122291590157914
# 2025-09-21 10:19:14,775 - root - INFO - F1: 0.9122291590157914
# INFO:root:Epoch 57, train loss: 0.007, val loss: 13984.188.
# 2025-09-21 10:19:14,777 - root - INFO - Epoch 57, train loss: 0.007, val loss: 13984.188.
# INFO:root:Early stopping overall:
# 2025-09-21 10:19:14,779 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 27 out of 30
# 2025-09-21 10:19:14,780 - root - INFO - EarlyStopping counter: 27 out of 30
# INFO:root:# of epoches: 58
# 2025-09-21 10:19:14,781 - root - INFO - # of epoches: 58
# 100%|██████████| 874/874 [16:34<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-21 10:35:49,332 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-21 10:35:49,682 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 27.84857940673828
# 2025-09-21 10:35:49,684 - root - INFO - MAE: 27.84857940673828
# INFO:root:SAE: 19.425622940063477
# 2025-09-21 10:35:49,686 - root - INFO - SAE: 19.425622940063477
# INFO:root:F1: 0.3703976435935199
# 2025-09-21 10:35:49,705 - root - INFO - F1: 0.3703976435935199
# INFO:root:Evaluate fridge:
# 2025-09-21 10:35:49,707 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 40.46002197265625
# 2025-09-21 10:35:49,710 - root - INFO - MAE: 40.46002197265625
# INFO:root:SAE: 22.22172737121582
# 2025-09-21 10:35:49,716 - root - INFO - SAE: 22.22172737121582
# INFO:root:F1: 0.7128745608596817
# 2025-09-21 10:35:49,726 - root - INFO - F1: 0.7128745608596817
# INFO:root:Evaluate microwave:
# 2025-09-21 10:35:49,728 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 26.789474487304688
# 2025-09-21 10:35:49,730 - root - INFO - MAE: 26.789474487304688
# INFO:root:SAE: 21.52663230895996
# 2025-09-21 10:35:49,732 - root - INFO - SAE: 21.52663230895996
# INFO:root:F1: 0.11223021582733812
# 2025-09-21 10:35:49,741 - root - INFO - F1: 0.11223021582733812
# INFO:root:Evaluate wash:
# 2025-09-21 10:35:49,745 - root - INFO - Evaluate wash:
# INFO:root:MAE: 13.16264820098877
# 2025-09-21 10:35:49,747 - root - INFO - MAE: 13.16264820098877
# INFO:root:SAE: 9.812092781066895
# 2025-09-21 10:35:49,749 - root - INFO - SAE: 9.812092781066895
# INFO:root:F1: 0.9266381766381766
# 2025-09-21 10:35:49,762 - root - INFO - F1: 0.9266381766381766
# INFO:root:Epoch 58, train loss: 0.007, val loss: 15465.513.
# 2025-09-21 10:35:49,765 - root - INFO - Epoch 58, train loss: 0.007, val loss: 15465.513.
# INFO:root:Early stopping overall:
# 2025-09-21 10:35:49,766 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 28 out of 30
# 2025-09-21 10:35:49,771 - root - INFO - EarlyStopping counter: 28 out of 30
# INFO:root:# of epoches: 59
# 2025-09-21 10:35:49,772 - root - INFO - # of epoches: 59
# 100%|██████████| 874/874 [16:33<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-21 10:52:23,068 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-21 10:52:23,401 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 35.737586975097656
# 2025-09-21 10:52:23,407 - root - INFO - MAE: 35.737586975097656
# INFO:root:SAE: 34.3062858581543
# 2025-09-21 10:52:23,411 - root - INFO - SAE: 34.3062858581543
# INFO:root:F1: 0.060656418778562524
# 2025-09-21 10:52:23,423 - root - INFO - F1: 0.060656418778562524
# INFO:root:Evaluate fridge:
# 2025-09-21 10:52:23,425 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 39.34614944458008
# 2025-09-21 10:52:23,427 - root - INFO - MAE: 39.34614944458008
# INFO:root:SAE: 22.220272064208984
# 2025-09-21 10:52:23,429 - root - INFO - SAE: 22.220272064208984
# INFO:root:F1: 0.7294291459761152
# 2025-09-21 10:52:23,437 - root - INFO - F1: 0.7294291459761152
# INFO:root:Evaluate microwave:
# 2025-09-21 10:52:23,439 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 21.24062156677246
# 2025-09-21 10:52:23,445 - root - INFO - MAE: 21.24062156677246
# INFO:root:SAE: 18.074024200439453
# 2025-09-21 10:52:23,447 - root - INFO - SAE: 18.074024200439453
# INFO:root:F1: 0.1569532602423543
# 2025-09-21 10:52:23,458 - root - INFO - F1: 0.1569532602423543
# INFO:root:Evaluate wash:
# 2025-09-21 10:52:23,459 - root - INFO - Evaluate wash:
# INFO:root:MAE: 17.312593460083008
# 2025-09-21 10:52:23,460 - root - INFO - MAE: 17.312593460083008
# INFO:root:SAE: 12.761459350585938
# 2025-09-21 10:52:23,462 - root - INFO - SAE: 12.761459350585938
# INFO:root:F1: 0.9287652645861602
# 2025-09-21 10:52:23,469 - root - INFO - F1: 0.9287652645861602
# INFO:root:Epoch 59, train loss: 0.007, val loss: 18804.660.
# 2025-09-21 10:52:23,471 - root - INFO - Epoch 59, train loss: 0.007, val loss: 18804.660.
# INFO:root:Early stopping overall:
# 2025-09-21 10:52:23,472 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 29 out of 30
# 2025-09-21 10:52:23,474 - root - INFO - EarlyStopping counter: 29 out of 30
# INFO:root:# of epoches: 60
# 2025-09-21 10:52:23,477 - root - INFO - # of epoches: 60
# 100%|██████████| 874/874 [16:34<00:00,  1.14s/it]
# INFO:root:Validation:
# 2025-09-21 11:08:58,052 - root - INFO - Validation:
# INFO:root:Evaluate dish washer:
# 2025-09-21 11:08:58,383 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 32.537559509277344
# 2025-09-21 11:08:58,385 - root - INFO - MAE: 32.537559509277344
# INFO:root:SAE: 23.73373031616211
# 2025-09-21 11:08:58,389 - root - INFO - SAE: 23.73373031616211
# INFO:root:F1: 0.2908054169636493
# 2025-09-21 11:08:58,400 - root - INFO - F1: 0.2908054169636493
# INFO:root:Evaluate fridge:
# 2025-09-21 11:08:58,402 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 41.657691955566406
# 2025-09-21 11:08:58,404 - root - INFO - MAE: 41.657691955566406
# INFO:root:SAE: 23.28763771057129
# 2025-09-21 11:08:58,407 - root - INFO - SAE: 23.28763771057129
# INFO:root:F1: 0.711157196184156
# 2025-09-21 11:08:58,414 - root - INFO - F1: 0.711157196184156
# INFO:root:Evaluate microwave:
# 2025-09-21 11:08:58,415 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 25.82489585876465
# 2025-09-21 11:08:58,417 - root - INFO - MAE: 25.82489585876465
# INFO:root:SAE: 22.411174774169922
# 2025-09-21 11:08:58,419 - root - INFO - SAE: 22.411174774169922
# INFO:root:F1: 0.05978567399887197
# 2025-09-21 11:08:58,427 - root - INFO - F1: 0.05978567399887197
# INFO:root:Evaluate wash:
# 2025-09-21 11:08:58,428 - root - INFO - Evaluate wash:
# INFO:root:MAE: 15.364479064941406
# 2025-09-21 11:08:58,430 - root - INFO - MAE: 15.364479064941406
# INFO:root:SAE: 12.542916297912598
# 2025-09-21 11:08:58,432 - root - INFO - SAE: 12.542916297912598
# INFO:root:F1: 0.9433611884865367
# 2025-09-21 11:08:58,440 - root - INFO - F1: 0.9433611884865367
# INFO:root:Epoch 60, train loss: 0.006, val loss: 18151.719.
# 2025-09-21 11:08:58,441 - root - INFO - Epoch 60, train loss: 0.006, val loss: 18151.719.
# INFO:root:Model saved
# 2025-09-21 11:08:58,595 - root - INFO - Model saved
# INFO:root:Early stopping overall:
# 2025-09-21 11:08:58,597 - root - INFO - Early stopping overall:
# INFO:root:EarlyStopping counter: 30 out of 30
# 2025-09-21 11:08:58,598 - root - INFO - EarlyStopping counter: 30 out of 30
# Early stopping
# INFO:root:Model loaded
# 2025-09-21 11:08:58,901 - root - INFO - Model loaded
# INFO:root:Training end
# 2025-09-21 11:08:58,918 - root - INFO - Training end
# INFO:root:validation start
# 2025-09-21 11:08:58,920 - root - INFO - validation start
# INFO:root:Evaluate dish washer:
# 2025-09-21 11:08:59,280 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 25.516632080078125
# 2025-09-21 11:08:59,282 - root - INFO - MAE: 25.516632080078125
# INFO:root:SAE: 13.090804100036621
# 2025-09-21 11:08:59,284 - root - INFO - SAE: 13.090804100036621
# INFO:root:F1: 0.4791666666666667
# 2025-09-21 11:08:59,294 - root - INFO - F1: 0.4791666666666667
# INFO:root:Evaluate fridge:
# 2025-09-21 11:08:59,295 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 35.389015197753906
# 2025-09-21 11:08:59,297 - root - INFO - MAE: 35.389015197753906
# INFO:root:SAE: 20.321292877197266
# 2025-09-21 11:08:59,299 - root - INFO - SAE: 20.321292877197266
# INFO:root:F1: 0.7677740592604685
# 2025-09-21 11:08:59,306 - root - INFO - F1: 0.7677740592604685
# INFO:root:Evaluate microwave:
# 2025-09-21 11:08:59,308 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 26.92841911315918
# 2025-09-21 11:08:59,310 - root - INFO - MAE: 26.92841911315918
# INFO:root:SAE: 25.6213436126709
# 2025-09-21 11:08:59,312 - root - INFO - SAE: 25.6213436126709
# INFO:root:F1: 0.026822157434402333
# 2025-09-21 11:08:59,319 - root - INFO - F1: 0.026822157434402333
# INFO:root:Evaluate wash:
# 2025-09-21 11:08:59,320 - root - INFO - Evaluate wash:
# INFO:root:MAE: 9.991584777832031
# 2025-09-21 11:08:59,323 - root - INFO - MAE: 9.991584777832031
# INFO:root:SAE: 6.213928699493408
# 2025-09-21 11:08:59,325 - root - INFO - SAE: 6.213928699493408
# INFO:root:F1: 0.9437441643323996
# 2025-09-21 11:08:59,332 - root - INFO - F1: 0.9437441643323996
# INFO:root:test start
# 2025-09-21 11:08:59,334 - root - INFO - test start
# INFO:root:Evaluate dish washer:
# 2025-09-21 11:09:07,233 - root - INFO - Evaluate dish washer:
# INFO:root:MAE: 17.852432250976562
# 2025-09-21 11:09:07,242 - root - INFO - MAE: 17.852432250976562
# INFO:root:SAE: 17.318782806396484
# 2025-09-21 11:09:07,257 - root - INFO - SAE: 17.318782806396484
# INFO:root:F1: 0.4886235072281584
# 2025-09-21 11:09:07,343 - root - INFO - F1: 0.4886235072281584
# INFO:root:Evaluate fridge:
# 2025-09-21 11:09:07,345 - root - INFO - Evaluate fridge:
# INFO:root:MAE: 35.46189498901367
# 2025-09-21 11:09:07,351 - root - INFO - MAE: 35.46189498901367
# INFO:root:SAE: 25.57856559753418
# 2025-09-21 11:09:07,366 - root - INFO - SAE: 25.57856559753418
# INFO:root:F1: 0.8331300147777877
# 2025-09-21 11:09:07,431 - root - INFO - F1: 0.8331300147777877
# INFO:root:Evaluate microwave:
# 2025-09-21 11:09:07,435 - root - INFO - Evaluate microwave:
# INFO:root:MAE: 27.544506072998047
# 2025-09-21 11:09:07,442 - root - INFO - MAE: 27.544506072998047
# INFO:root:SAE: 20.756696701049805
# 2025-09-21 11:09:07,457 - root - INFO - SAE: 20.756696701049805
# INFO:root:F1: 0.24032775480230356
# 2025-09-21 11:09:07,521 - root - INFO - F1: 0.24032775480230356
# INFO:root:Evaluate wash:
# 2025-09-21 11:09:07,524 - root - INFO - Evaluate wash:
# INFO:root:MAE: 39.9283332824707
# 2025-09-21 11:09:07,530 - root - INFO - MAE: 39.9283332824707
# INFO:root:SAE: 32.96866226196289
# 2025-09-21 11:09:07,547 - root - INFO - SAE: 32.96866226196289
# INFO:root:F1: 0.4627035213934116
# 2025-09-21 11:09:07,617 - root - INFO - F1: 0.4627035213934116
